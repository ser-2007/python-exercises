# %% [markdown]
# ### Exceptions

# %%
try:
    x=3/0
except:
    print("Wrong")
finally:
    print("Always execute")
# Out:
# Wrong
# Always execute

# %%
try:
    x=3/0
except ZeroDivisionError:
    print("Attempt to divide by zero")
finally:
    print("Something else went wrong")
# Out:
# Attempt to divide by zero
# Something else went wrong

# %%
fruits = ["banana", "mango", "pear", "apple", "kiwi", "grape"]

while True:
    try:
        index = int(input("enter your favoruite fruit index number"))
        print("My favotuite fruit is {} ".format(fruits[index]))
        break
    except IndexError:
        print("index is not true. Please enter true index number")
    except ValueError:
        print("Enter a true value")
# Out:
# enter your favoruite fruit index number6
# index is not true. Please enter true index number
# enter your favoruite fruit index number2
# My favotuite fruit is pear

# %% [markdown]
# ### ![image.png](attachment:image.png)

# %%
fruits = ["banana", "mango", "pear", "apple", "kiwi", "grape"]
count =3

while count>0:
    try:
        index = int(input("enter your favoruite fruit index number"))
        print("My favotuite fruit is {} ".format(fruits[index]))
      
        break
    except IndexError:
        count -=1
        print(f"index is not true. Please enter true index number.you can try only {count} times")
        
    except ValueError:
        count -= 1
        print(f"Enter a true and integer value, try again. You try {count} times only.")
    else:
        print("Congragulations. You entered true") 
        break
        
    finally:
        print("Our fruits are always fresh")
# Out:
# enter your favoruite fruit index number6
# index is not true. Please enter true index number.you can try only 2 times
# Our fruits are always fresh
# enter your favoruite fruit index number6
# index is not true. Please enter true index number.you can try only 1 times
# Our fruits are always fresh
# enter your favoruite fruit index number9
# index is not true. Please enter true index number.you can try only 0 times
# Our fruits are always fresh

# %%
hak = 3
while hak > 0 :
    try :
        index = int(input("Favori meyve indexini girer misin? : "))
        print("Benim favori meyvem {}'dir.".format(fruits[index]))
        break
    except IndexError :
        print("Böyle bir index bulunmamaktadır. Lütfen doğru giriş yapınız.")
        hak -= 1
    except ValueError :
        print("Integer yani numeric bir değer giriniz. Tekrar deneyin.")
    finally:
        print("Mevelerimiz her daim tazedir.")
# Out:
# Favori meyve indexini girer misin? : 6
# Böyle bir index bulunmamaktadır. Lütfen doğru giriş yapınız.
# Mevelerimiz her daim tazedir.
# Favori meyve indexini girer misin? : 9
# Böyle bir index bulunmamaktadır. Lütfen doğru giriş yapınız.
# Mevelerimiz her daim tazedir.
# Favori meyve indexini girer misin? : 5
# Benim favori meyvem grape'dir.
# Mevelerimiz her daim tazedir.

# %%
fruits = ["banana", "mango", "pear", "apple", "kiwi", "grape"]
count=3
while count>0:
    try :
        index = int(input("Favori meyve indexini girer misin? : "))
        print("Benim favori meyvem {}'dir.".format(fruits[index]))
     
    except IndexError :
        c -= 1
        print(f"Böyle bir index bulunmamaktadır. {count} hakkiniz kaldi.")
        
    except ValueError :
        c -= 1
        print(f"Integer yani numeric bir değer giriniz.{count} hakkiniz kaldi.")
       
    else:
      print("Tebrikler.. Dogru giris yaptiniz..")
      break
    finally:
      print("Meyvelerim tazedir afiyet ossun")
# Out:
# Favori meyve indexini girer misin? : 3
# Benim favori meyvem apple'dir.
# Tebrikler.. Dogru giris yaptiniz..
# Meyvelerim tazedir afiyet ossun
